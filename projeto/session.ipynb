# %%
# Importando bibliotecas
import requests
import dotenv
import os
import json
from urllib.parse import urljoin

# Carregando as variáveis do arquivo .env
dotenv.load_dotenv(override=True)
api_username = os.getenv('API_USERNAME')
api_password = os.getenv('API_PASSWORD')
api_url = os.getenv('API_URL')

# %%
print(api_password)
print(api_username)
print(api_url)
# Out:
# ER8Bg9q@GJM6z
# painelbi@svriglobal.com
# https://api.polotrial.com

# %%
# Iniciando a sessão
# Corpo do login a ser utilizado no acesso
body = {
    "nome": api_username,
    "password":api_password
}

# Obtençao do token de acesso à polotrial
auth_url = urljoin(api_url, "/sessions")

response = requests.post(auth_url, json = body)

# # Verificar a resposta
# print(f"Status Code: {response.status_code}")
# print(f"Headers: {response.headers}")
# print(f"Content: {response.text}")

# Extraindo o token

# %%
token = response.json()
token
# Out:
# {'user': {'id': 232,
#   'nome': 'painelbi@svriglobal.com',
#   'cliente': 'svriplayground',
#   'data': {'displayName': 'painelbi@svriglobal.com',
#    'email': 'painelbi@svriglobal.com',
#    'photoURL': 'assets/images/avatars/Abbott.jpg',
#    'allowedPages': {'/calendar': ['SELECT', 'UPDATE'],
#     '/quality_attachments': ['SELECT'],
#     '/quality_attachments/:id': ['SELECT', 'UPDATE'],
#     'quality_attachments': ['SELECT', 'UPDATE'],
#     'flowcharts': ['SELECT', 'UPDATE'],
#     '/flowcharts': ['SELECT',
#      'SELECT',
#      'SELECT',
#      'SELECT',
#      'SELECT',
#      'SELECT'],
#     '/flowcharts/:id': ['SELECT',
#      'UPDATE',
#      'SELECT',
#      'UPDATE',
#      'SELECT',
#      'UPDATE',
#      'SELECT',
#      'SELECT',
#      'UPDATE',
#      'UPDATE'],
#     '/sites': ['SELECT'],
#     '/sites/:id': ['SELECT', 'UPDATE'],
#     'sites': ['SELECT', 'UPDATE'],
#     '/contracts': ['SELECT'],
#     '/contracts/:id': ['SELECT', 'UPDATE'],
#     'contracts': ['SELECT', 'UPDATE'],
#     '/deviations': ['SELECT'],
#     '/deviations/:id': ['SELECT', 'UPDATE'],
#     'deviations': ['SELECT', 'UPDATE'],
#     '/equipments': ['SELECT'],
#     '/equipments/:id': ['SELECT', 'UPDATE'],
#     'equipments': ['SELECT', 'UPDATE'],
#     '/equipmentsProtocols': ['SELECT'],
#     '/equipmentsProtocols/:id': ['SELECT', 'UPDATE'],
#     'equipmentsProtocols': ['SELECT', 'UPDATE'],
#     'equipments_protocols': ['SELECT', 'UPDATE'],
#     '/protocol_team': ['SELECT'],
#     '/protocol_team/:id': ['SELECT', 'UPDATE'],
#     'protocol_team': ['SELECT', 'UPDATE', 'UPDATE', 'SELECT'],
#     'protocolTeam': ['UPDATE', 'SELECT', 'SELECT', 'UPDATE'],
#     '/adverseEvents': ['SELECT'],
#     '/adverseEvents/:id': ['SELECT', 'UPDATE'],
#     'adverseEvents': ['SELECT', 'UPDATE', 'SELECT', 'UPDATE'],
#     '/adverse_events': ['SELECT', 'SELECT'],
#     '/adverse_events/:id': ['SELECT', 'UPDATE', 'SELECT', 'UPDATE'],
#     'adverse_events': ['SELECT', 'UPDATE', 'SELECT', 'UPDATE'],
#     '/suppliers': ['SELECT'],
#     '/suppliers/:id': ['SELECT', 'UPDATE'],
#     'suppliers': ['SELECT', 'UPDATE'],
#     '/dashboard': ['SELECT', 'SELECT'],
#     '/auth/user-role': ['SELECT', 'SELECT'],
#     '/example': ['SELECT', 'SELECT'],
#     '/logout': ['SELECT', 'SELECT'],
#     '/data_types': ['SELECT', 'SELECT', 'SELECT'],
#     '/data_types/:id': ['SELECT', 'UPDATE', 'SELECT'],
#     'data_types': ['SELECT', 'UPDATE', 'SELECT', 'UPDATE'],
#     '/supplies': ['SELECT'],
#     'supplies': ['SELECT', 'UPDATE'],
#     '/supplies/:id': ['SELECT'],
#     '/supply_categories': ['SELECT'],
#     '/supply_categories/:id': ['SELECT', 'UPDATE'],
#     'supply_categories': ['SELECT', 'UPDATE'],
#     '/supplyCategoryTypes': ['SELECT'],
#     '/supplyCategoryTypes/:id': ['SELECT', 'UPDATE'],
#     'supplyCategoryTypes': ['SELECT', 'UPDATE'],
#     '/inSupply': ['SELECT'],
#     '/inSupply/:id': ['SELECT', 'UPDATE'],
#     'inSupply': ['SELECT', 'UPDATE'],
#     'insumo_entrada': ['SELECT', 'UPDATE'],
#     '/supplies_responsibilities': ['SELECT'],
#     '/supplies_responsibilities/:id': ['SELECT', 'UPDATE'],
#     'supplies_responsibilities': ['SELECT', 'UPDATE'],
#     '/outSupply': ['SELECT'],
#     '/outSupply/:id': ['SELECT', 'UPDATE'],
#     'outSupply': ['SELECT', 'UPDATE'],
#     'insumo_saida': ['SELECT', 'UPDATE'],
#     '/supply_requests': ['SELECT'],
#     '/supply_requests/:id': ['SELECT', 'UPDATE'],
#     'supply_requests': ['SELECT', 'UPDATE'],
#     '/kanban': ['SELECT'],
#     '/kanban/boards': ['SELECT'],
#     '/kanban/boards/:boardId': ['SELECT', 'UPDATE'],
#     '/monitoring': ['SELECT'],
#     '/monitoring/:id': ['SELECT', 'UPDATE'],
#     'monitoring': ['SELECT', 'UPDATE'],
#     '/payments': ['SELECT'],
#     '/payments/:id': ['SELECT', 'UPDATE'],
#     'payments': ['SELECT', 'UPDATE'],
#     'pagamento_item': ['SELECT', 'UPDATE'],
#     '/participants/:participantId': ['UPDATE', 'SELECT'],
#     '/participants': ['SELECT'],
#     '/participante_visita_procedimento': ['SELECT'],
#     '/participante_visita_procedimento/:id': ['SELECT', 'UPDATE'],
#     'participante_visita_procedimento': ['SELECT', 'UPDATE'],
#     '/executors': ['SELECT'],
#     '/executors/:id': ['SELECT', 'UPDATE'],
#     'executors': ['SELECT', 'UPDATE'],
#     '/people': ['SELECT'],
#     '/people/:id': ['SELECT', 'UPDATE'],
#     'people': ['SELECT', 'UPDATE'],
#     '/post_studies': ['SELECT'],
#     '/post_studies/:id': ['SELECT', 'UPDATE'],
#     'post_studies': ['SELECT', 'UPDATE'],
#     '/first_access': ['SELECT', 'SELECT'],
#     '/protocols': ['SELECT'],
#     '/protocols/:id': ['SELECT', 'UPDATE'],
#     'protocols': ['SELECT', 'UPDATE'],
#     '/protocol_attachments': ['SELECT'],
#     '/protocol_attachments/:id': ['SELECT', 'UPDATE'],
#     'protocol_attachments': ['SELECT', 'UPDATE'],
#     'protocolAttachments': ['SELECT', 'UPDATE'],
#     '/protocol_feasibility': ['SELECT'],
#     '/protocol_feasibility/:id': ['SELECT', 'UPDATE'],
#     'protocol_feasibility': ['SELECT', 'UPDATE'],
#     '/protocol_financial': ['SELECT'],
#     '/protocol_financial/:id': ['SELECT', 'UPDATE'],
#     'protocol_financial': ['SELECT', 'UPDATE'],
#     '/protocol_procedures': ['SELECT'],
#     '/protocol_procedures/:id': ['SELECT', 'UPDATE'],
#     'protocol_procedures': ['SELECT', 'UPDATE'],
#     '/incomes': ['SELECT'],
#     '/incomes/:id': ['SELECT', 'UPDATE'],
#     'incomes': ['SELECT', 'UPDATE'],
#     'recebimento_item': ['SELECT', 'UPDATE'],
#     '/regulations': ['SELECT'],
#     '/regulations/:id': ['SELECT', 'UPDATE'],
#     'regulations': ['SELECT', 'UPDATE'],
#     '/regulation_attachements': ['SELECT'],
#     '/regulation_attachements/:id': ['SELECT', 'UPDATE'],
#     'regulation_attachements': ['SELECT', 'UPDATE'],
#     '/fees': ['SELECT'],
#     '/fees/:id': ['SELECT', 'UPDATE'],
#     'fees': ['SELECT', 'UPDATE'],
#     '/usersPolo': ['SELECT', 'UPDATE'],
#     '/usersPolo/:id': ['SELECT', 'UPDATE'],
#     '/users': ['SELECT'],
#     '/users/:id': ['SELECT', 'UPDATE'],
#     'users_polo': ['SELECT', 'UPDATE'],
#     '/visits/:visitId': ['UPDATE', 'SELECT'],
#     '/visits': ['SELECT'],
#     '/volunteers': ['SELECT'],
#     '/volunteers/:id': ['SELECT', 'UPDATE'],
#     'volunteers': ['SELECT', 'UPDATE']},
#    'settings': {'customScrollbars': True,
#     'layout': {'style': 'layout1',
#      'config': {'footer': {'display': True,
#        'style': 'fixed',
#        'position': 'below'},
#       'mode': 'fullwidth',
#       'navbar': {'display': True, 'folded': True, 'position': 'left'},
#       'scroll': 'content',
#       'toolbar': {'display': True, 'style': 'fixed', 'position': 'below'}},
#      'theme': {'footer': 'defaultDark',
#       'main': 'defaultDark',
#       'navbar': 'defaultDark',
#       'toolbar': 'defaultDark'}}},
#    'shortcuts': ['calendar', 'mail', 'contacts']},
#   'redirectUrl': '/example',
#   'role': 'Admin'},
#  'token': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpYXQiOjE3NTMzMDY5MTgsImV4cCI6MTc1MzM5MzMxOCwic3ViIjoie1widXNlcl9pZFwiOjY0MjYsXCJpc19hZG1pblwiOjAsXCJjb19wZXNzb2FcIjoyMzJ9In0.7OxmZStf-yYR7QnE23lQOseCEJAbFzFAuWncEiTARrg'}
